# %% [markdown]
# > **Branch:** `feature/stage9-deployment`
# > **Author:** Jia
# > ⚠️ **Before running:** Make sure you have already run `stage00_dataset_generator.ipynb` in the same Colab session so that `/content/dataset` and all shared variables are available.

# %% [markdown]
# ---
# # STAGE 9 — Deployment (Streamlit)
# **Author: Jia**
# **Branch: feature/stage9-deployment**
#
# ---
#
# The Streamlit app (`app.py`) is created as a **separate file** and deployed to Streamlit Community Cloud.
#
# See `app.py` in the repository root for the full deployment code.
#
# **Live URL:** *(add after deployment)*

# %%
# ============================================================
# STAGE 9 — DEPLOYMENT
# Author: Jia
# The app.py file is uploaded separately to GitHub
# ============================================================

# Save the scaler so app.py can use it
import joblib
joblib.dump(scaler, 'models/scaler.pkl')
print("✅ Scaler saved to models/scaler.pkl")
print("✅ SVM model saved to models/svm_model.pkl")
print()
print("Next steps for Jia:")
print("1. Download models/svm_model.pkl and models/scaler.pkl")
print("2. Upload both to GitHub under models/ folder")
print("3. Create app.py (code provided separately)")
print("4. Upload app.py and requirements.txt to GitHub root")
print("5. Deploy on Streamlit Community Cloud")
print("\nStage 9 Setup Complete ✅")
# Out:
# ✅ Scaler saved to models/scaler.pkl
# ✅ SVM model saved to models/svm_model.pkl
#
# Next steps for Jia:
# 1. Download models/svm_model.pkl and models/scaler.pkl
# 2. Upload both to GitHub under models/ folder
# 3. Create app.py (code provided separately)
# 4. Upload app.py and requirements.txt to GitHub root
# 5. Deploy on Streamlit Community Cloud
#
# Stage 9 Setup Complete ✅

# %%
from google.colab import files

# Download all 4 model files
files.download('models/svm_model.pkl')
files.download('models/knn_model.pkl')
files.download('models/dt_model.pkl')
files.download('models/scaler.pkl')
