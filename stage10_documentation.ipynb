# %% [markdown]
# > **Branch:** `feature/stage10-documentation`
# > **Author:** Theertha
# > ⚠️ **Before running:** Make sure you have already run `stage00_dataset_generator.ipynb` in the same Colab session so that `/content/dataset` and all shared variables are available.

# %% [markdown]
# ---
# # STAGE 10 — Documentation
# **Author: Theertha**
# **Branch: feature/stage10-documentation**
#
# ---

# %%
# ============================================================
# STAGE 10 — DOCUMENTATION SUMMARY
# Author: Theertha
# ============================================================

print("="*60)
print(" MATHEMATICAL OPERATOR SYMBOL CLASSIFICATION")
print(" Project Summary")
print("="*60)
print(f"\n Team: Adithyan | Jia | Theertha")
print(f"\n Dataset: Kaggle — Handwritten Math Symbols")
print(f" Classes: +  −  ×  ÷  =  ≠  <  >  ±  √")
print(f"\n Features used:")
print(f"   - HOG (orientations=9, pixels_per_cell=(4,4))")
print(f"   - Projection Profiles (horizontal + vertical)")
print(f"   - Pixel Run-Length Features")
print(f"\n Models trained:")
print(f"   - SVM (RBF kernel, C=10)")
print(f"   - KNN (best k selected by CV)")
print(f"   - Decision Tree (best depth selected by CV)")
print(f"\n Evaluation metric: Macro F1-score + Confusion Matrix")
print(f"\n Deployment: Streamlit Community Cloud")
print(f"\n GitHub: [repository URL]")
print(f"\n Live App: [streamlit URL]")
print("\n" + "="*60)
print(" ALL 10 STAGES COMPLETE ✅")
print("="*60)
# Out:
# ...
#  MATHEMATICAL OPERATOR SYMBOL CLASSIFICATION
#  Project Summary
# ...
#
#  Team: Adithyan | Jia | Theertha
#
#  Dataset: Kaggle — Handwritten Math Symbols
#  Classes: +  −  ×  ÷  =  ≠  <  >  ±  √
#
#  Features used:
#    - HOG (orientations=9, pixels_per_cell=(4,4))
#    - Projection Profiles (horizontal + vertical)
#    - Pixel Run-Length Features
#
#  Models trained:
#    - SVM (RBF kernel, C=10)
#    - KNN (best k selected by CV)
#    - Decision Tree (best depth selected by CV)
#
#  Evaluation metric: Macro F1-score + Confusion Matrix
#
#  Deployment: Streamlit Community Cloud
#
#  GitHub: [repository URL]
#
#  Live App: [streamlit URL]
#
# ...
#  ALL 10 STAGES COMPLETE ✅
# ...
